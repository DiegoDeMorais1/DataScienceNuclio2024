# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
wine = pd.read_csv('assets/wines.csv')

# %%
wine.head()
# Out:
#    Fortified  Drywhite  Sweetwhite   Red   Rose  Sparkling      date
# 0       2585      1954          85   464  112.0       1686  Jan 1980
# 1       3368      2302          89   675  118.0       1591  Feb 1980
# 2       3210      3054         109   703  129.0       2304  Mar 1980
# 3       3111      2414          95   887   99.0       1712  Apr 1980
# 4       3756      2226          91  1139  116.0       1471  May 1980

# %%
wine.set_index('date', inplace=True)
wine.index = pd.to_datetime(wine.index)

# %%
wine.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %%
from src.tde import UnivariateTDE

# %%
# desta vez fazemos a divisão no tempo
train_end = pd.Timestamp('1993-12-01')
test_start = pd.Timestamp('1994-01-01')

# %%
training, testing, mean_value = {}, {}, {}
for col in wine.columns:
    # últimos 6 meses para validação
    train = wine.loc[:train_end, col]
    test = wine.loc[test_start:, col]

    # normalização com dados de TREINO!
    mean_value[col] = train.mean()
    train /= mean_value[col]
    test /= mean_value[col]

    # serie temporal como matriz
    training[col] = UnivariateTDE(train, horizon=1, k=4)
    testing[col] = UnivariateTDE(test, horizon=1, k=4)

# %%
training['Sparkling'].head()
# Out:
#         t-3       t-2       t-1       t-0       t+1
# 0  0.694154  0.655041  0.948594  0.704858  0.605635
# 1  0.655041  0.948594  0.704858  0.605635  0.566933
# 2  0.948594  0.704858  0.605635  0.566933  0.809434
# 3  0.704858  0.605635  0.566933  0.809434  1.009940
# 4  0.605635  0.566933  0.809434  1.009940  0.816845

# %%
# concatenando as matrizes
train_df = pd.concat(training, axis=0)
train_df.head()
# Out:
#                   t-3       t-2       t-1       t-0       t+1
# Fortified 0  0.849065  1.106249  1.054352  1.021835  1.233690
#           1  1.106249  1.054352  1.021835  1.233690  1.384781
#           2  1.054352  1.021835  1.233690  1.384781  1.716196
#           3  1.021835  1.233690  1.384781  1.716196  1.453758
#           4  1.233690  1.384781  1.716196  1.453758  1.291499

# %%
train_df.tail()
# Out:
#                     t-3       t-2       t-1       t-0       t+1
# Sparkling 159  0.873250  0.753852  0.623750  0.843195  1.150747
#           160  0.753852  0.623750  0.843195  1.150747  0.720092
#           161  0.623750  0.843195  1.150747  0.720092  1.374721
#           162  0.843195  1.150747  0.720092  1.374721  1.740325
#           163  1.150747  0.720092  1.374721  1.740325  2.639101

# %%
testing['Sparkling'].head()
# Out:
#         t-3       t-2       t-1       t-0       t+1
# 0  0.492824  0.810258  0.708152  0.710211  0.689213
# 1  0.810258  0.708152  0.710211  0.689213  0.697036
# 2  0.708152  0.710211  0.689213  0.697036  0.836196
# 3  0.710211  0.689213  0.697036  0.836196  0.615516
# 4  0.689213  0.697036  0.836196  0.615516  1.221974

# %%
X_train = train_df.drop('t+1', axis=1)
y_train = train_df['t+1']

# %%
from sklearn.linear_model import Ridge
# treinando o modelo global
global_model = Ridge()
global_model.fit(X_train, y_train)
# Out:
# Ridge()

# %%
# previsão
X_test = testing['Sparkling'].drop('t+1', axis=1)
global_forecasts = global_model.predict(X_test)
# revertendo a normalização
global_forecasts *= mean_value['Sparkling']

# %%
X_train_local = training['Sparkling'].drop('t+1', axis=1)
y_train_local = training['Sparkling']['t+1']

# treinando o modelo local
local_model = Ridge()
local_model.fit(X_train_local, y_train_local)
# Out:
# Ridge()

# %%
# previsão
X_test = testing['Sparkling'].drop('t+1', axis=1)
local_forecasts = local_model.predict(X_test)

local_forecasts *= mean_value['Sparkling']

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(testing['Sparkling']['t+1'], global_forecasts)
# Out:
# 2345.73152651055

# %%
mean_absolute_error(testing['Sparkling']['t+1'], local_forecasts)
# Out:
# 2414.874443346605
